# %% [markdown]
# <h3>Does precipitation level has anything to do with accident count?</h3>
#
# `US_Accidents_Dec21_updated.csv` and `WeatherEvents_Jan2016-Dec2021.csv` are the main data.<br>
# `US_Accidents_Dec21_updated.csv` - accident records for all the states.<br>
# `WeatherEvents_Jan2016-Dec2021.csv` - weather events for all the states.<br><br>
#
# Data of 5 cities from different states are extracted and combined.<br>
# Producing 5 tables, `[City].csv`, which has **date** (2016-01-01 -> 2021-12-31) as row.

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
names = ["Denver", "Miami", "Minneapolis", "New York", "Phoenix"]
category = ['W0000_0600','W0601_1200','W1201_1800','W1801_2359','WS1','WS2','WS3','WS4','AS0000_0600','AS0601_1200','AS1201_1800','AS1801_2359','Accident']
city_count = len(names)
cities = [ 
 pd.read_csv(names[0] + '.csv')
,pd.read_csv(names[1] + '.csv')
,pd.read_csv(names[2] + '.csv')
,pd.read_csv(names[3] + '.csv')
,pd.read_csv(names[4] + '.csv')
]
cities_cat = []
for i in range(city_count):
	cities_cat.append(cities[i][category].astype('category'))

# %%
cities_cat[0].describe()
# Out:
#        W0000_0600 W0601_1200 W1201_1800 W1801_2359    WS1    WS2    WS3  \
# count        2192       2192       2192       2192    506    342    344
# unique          7          6          6          6      5      4      4
# top         Clear      Clear      Clear      Clear  Light  Light  Light
# freq         1686       1850       1848       1784    394    236    156
#
#           WS4  AS0000_0600  AS0601_1200  AS1201_1800  AS1801_2359 Accident
# count     408         2192         2192         2192         2192     2192
# unique      5            5            5            5            5        2
# top     Light            0            0            0            0     True
# freq      304         1244         1165         1495         1929     1476

# %%
print("Weather type: ", cities_cat[0]['W0000_0600'].unique(), end ='\n\n')
print("Weather severity: ", cities_cat[0]['WS1'].unique(), end ='\n\n')
print("Accident severity: ", cities_cat[0]['AS0000_0600'].unique())
print("Dimension: ", cities[0].shape[0], "x", cities[0].shape[1])
# Out:
# Weather type:  ['Clear', 'Snow', 'Fog', 'Storm', 'Rain', 'Precipitation', 'Cold']
# Categories (7, object): ['Clear', 'Snow', 'Fog', 'Storm', 'Rain', 'Precipitation', 'Cold']
#
# Weather severity:  [NaN, 'Light', 'Moderate', 'Severe', 'UNK', 'Heavy']
# Categories (5, object): ['Light', 'Moderate', 'Severe', 'UNK', 'Heavy']
#
# Accident severity:  [0, 2, 3, 4, 1]
# Categories (5, int64): [0, 2, 3, 4, 1]
# Dimension:  2192 x 16

# %%
cities[0].corr() # this is just for the first city
# Out:
#              AS0000_0600  AS0601_1200  AS1201_1800  AS1801_2359  P_Value(in)  \
# AS0000_0600     1.000000     0.419955     0.281306     0.074568     0.007494
# AS0601_1200     0.419955     1.000000     0.342712     0.096925    -0.011970
# AS1201_1800     0.281306     0.342712     1.000000     0.129609    -0.013796
# AS1801_2359     0.074568     0.096925     0.129609     1.000000     0.000089
# P_Value(in)     0.007494    -0.011970    -0.013796     0.000089     1.000000
# A_Total         0.472691     0.480028     0.479828     0.171389    -0.005981
# Accident        0.578661     0.622771     0.455465     0.247256    -0.046722
#
#               A_Total  Accident
# AS0000_0600  0.472691  0.578661
# AS0601_1200  0.480028  0.622771
# AS1201_1800  0.479828  0.455465
# AS1801_2359  0.171389  0.247256
# P_Value(in) -0.005981 -0.046722
# A_Total      1.000000  0.476280
# Accident     0.476280  1.000000

# %% [markdown]
# Types of analysis:
#    1. Correlation Matrix / Heatmap [ sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f") ]
#    2. No. of Weathers that occur from 2016 to 2021
#    3. Uni-Variate Linear Regression (Predictor = precipitation)
#    4. Goodness of Fit of the Model
#    5. Regression with random train-test split
#    6. Simple Decision tree (Response = Accident[T/F], Predictor = precipitation) [done in
#    7. Classification tree with Random Train-Test Split [done]
#    8. Prediction of Accident [can be done after finalising the rest]

# %%
f, axes = plt.subplots(2, 3, figsize=(25, 15))

for i in range(5):  # correlation for all city
	sb.heatmap(cities[i].corr(), ax = axes[int(i/3),i%3], cmap = "RdBu")

# %% [markdown]
# It seems to be have no relationship between preciptation level and accident count.

# %% [markdown]
# <h3>Weather type vs Accident count</h3>
#
# Row order: 1. Denver 2. Miami 3. Minneapolis 4. New York 5. Phoenix

# %%
f, axes = plt.subplots(5, 4, figsize=(30, 17))
for i in range(city_count):
	for j in range(4):
		sb.boxplot(x = 'A_Total', y = category[j] , data = cities[i], orient = 'h', ax = axes[i,j])

# %% [markdown]
# <h3>Weather serverity vs Accident count</h3>
#
# Row order: 1. Denver 2. Miami 3. Minneapolis 4. New York 5. Phoenix

# %%
f, axes = plt.subplots(5, 4, figsize=(30, 15))
for i in range(city_count):
	for j in range(4):
		sb.boxplot(x = 'A_Total', y = category[j + 4] , data = cities[i], orient = 'h', ax = axes[i,j])

# %% [markdown]
# <h3>Getting week summary of weather events and accident count</h3>
#
# New tables will be generated and stored in `cities_week`<br>
# Columns will be `weather types` and `A_total (in week)`<br>

# %%
row_init = cities[0].shape[0]
row_count = int(row_init / 7)
type_str = cities[0]['W0000_0600'].unique()
type_count = len(type_str)
col_order = type_str.tolist()

col_order.append("Events")
col_order.append("A_Total")
col_order.append("P_Value(in)")
cities_week = [[]] * city_count
for i in range(city_count):
	cities_week[i] = [[]] * row_count

print("Col order:", col_order)
# this part requires some time to sum up the records every 7 days
for i in range(city_count):
	accumulate = [0 for i in range(type_count + 3)]
	for j in range(row_init):
		if j%7 == 0 and j != 0:
			for k in range(1, type_count):
				accumulate[type_count] = accumulate[type_count] + accumulate[k]
			cities_week[i][int(j/7)-1] = accumulate
			accumulate = [0 for i in range(type_count + 3)]
		for k in range(type_count):
			for c in range(4): # category 0, 1, 2, 3
				if cities[i][category[c]][j] == type_str[k]:
					accumulate[k] = accumulate[k] + 1
		accumulate[type_count + 1] = accumulate[type_count + 1] + cities[i]['A_Total'][j]
		accumulate[type_count + 2] = accumulate[type_count + 2] + cities[i]['P_Value(in)'][j]

print("Captured: ", len(cities_week), "cities,", len(cities_week[0]), "rows,", len(cities_week[0][312]), "columns")
for i in range(city_count):
	cities_week[i] = pd.DataFrame.from_records(cities_week[i], columns=col_order)
# Out:
# Col order: ['Clear', 'Snow', 'Fog', 'Storm', 'Rain', 'Precipitation', 'Cold', 'Events', 'A_Total', 'P_Value(in)']
# Captured:  5 cities, 313 rows, 10 columns

# %%
cities_week[0].head(2) # summary of first 7 days from cities[0]
# Out:
#    Clear  Snow  Fog  Storm  Rain  Precipitation  Cold  Events  A_Total  \
# 0     25     3    0      0     0              0     0       3        0
# 1     20     6    2      0     0              0     0       8        0
#
#    P_Value(in)
# 0         0.39
# 1         0.31

# %%
cities[0].head(14) # calculate the amount of 'Clear' and 'Snow' and compare it with the out put of previous cells
# Out:
#          Date W0000_0600 W0601_1200 W1201_1800 W1801_2359       WS1       WS2  \
# 0    1/1/2016      Clear      Clear      Clear      Clear       NaN       NaN
# 1    1/2/2016      Clear      Clear      Clear      Clear       NaN       NaN
# 2    1/3/2016      Clear      Clear      Clear      Clear       NaN       NaN
# 3    1/4/2016      Clear      Clear      Clear      Clear       NaN       NaN
# 4    1/5/2016      Clear      Clear      Clear      Clear       NaN       NaN
# 5    1/6/2016      Clear      Clear      Clear      Clear       NaN       NaN
# 6    1/7/2016      Clear       Snow       Snow       Snow       NaN     Light
# 7    1/8/2016      Clear       Snow       Snow       Snow       NaN  Moderate
# 8    1/9/2016       Snow      Clear      Clear       Snow     Light       NaN
# 9   1/10/2016      Clear        Fog       Snow      Clear       NaN    Severe
# 10  1/11/2016        Fog      Clear      Clear      Clear  Moderate       NaN
# 11  1/12/2016      Clear      Clear      Clear      Clear       NaN       NaN
# 12  1/13/2016      Clear      Clear      Clear      Clear       NaN       NaN
# 13  1/14/2016      Clear      Clear      Clear      Clear       NaN       NaN
#
#       WS3    WS4  AS0000_0600  AS0601_1200  AS1201_1800  AS1801_2359  \
# 0     NaN    NaN            0            0            0            0
# 1     NaN    NaN            0            0            0            0
# 2     NaN    NaN            0            0            0            0
# 3     NaN    NaN            0            0            0            0
# 4     NaN    NaN            0            0            0            0
# 5     NaN    NaN            0            0            0            0
# 6   Light  Light            0            0            0            0
# 7   Light  Light            0            0            0            0
# 8     NaN  Light            0            0            0            0
# 9   Light    NaN            0            0            0            0
# 10    NaN    NaN            0            0            0            0
# 11    NaN    NaN            0            0            0            0
# 12    NaN    NaN            0            0            0            0
# 13    NaN    NaN            0            0            0            0
#
#     P_Value(in)  A_Total  Accident
# 0          0.00        0     False
# 1          0.00        0     False
# 2          0.00        0     False
# 3          0.00        0     False
# 4          0.00        0     False
# 5          0.00        0     False
# 6          0.39        0     False
# 7          0.30        0     False
# 8          0.01        0     False
# 9          0.00        0     False
# 10         0.00        0     False
# 11         0.00        0     False
# 12         0.00        0     False
# 13         0.00        0     False

# %%
cities_week[1].corr() # unfortunately, there are still no relations between weather and accident count
# Out:
#                   Clear      Snow       Fog     Storm      Rain  \
# Clear          1.000000 -0.010711 -0.070770  0.032004 -0.896279
# Snow          -0.010711  1.000000  0.123985 -0.046715 -0.149684
# Fog           -0.070770  0.123985  1.000000 -0.010263 -0.249914
# Storm          0.032004 -0.046715 -0.010263  1.000000 -0.094803
# Rain          -0.896279 -0.149684 -0.249914 -0.094803  1.000000
# Precipitation -0.249017 -0.091996 -0.035288 -0.091111  0.131329
# Cold          -0.153613 -0.104073 -0.082596  0.126901 -0.058250
# Events        -1.000000  0.010711  0.070770 -0.032004  0.896279
# A_Total       -0.072154  0.017030  0.192506  0.160381 -0.038443
# P_Value(in)   -0.522621 -0.107933 -0.184582 -0.103301  0.540507
#
#                Precipitation      Cold    Events   A_Total  P_Value(in)
# Clear              -0.249017 -0.153613 -1.000000 -0.072154    -0.522621
# Snow               -0.091996 -0.104073  0.010711  0.017030    -0.107933
# Fog                -0.035288 -0.082596  0.070770  0.192506    -0.184582
# Storm              -0.091111  0.126901 -0.032004  0.160381    -0.103301
# Rain                0.131329 -0.058250  0.896279 -0.038443     0.540507
# Precipitation       1.000000 -0.036734  0.249017  0.126519     0.461952
# Cold               -0.036734  1.000000  0.153613  0.061471    -0.032318
# Events              0.249017  0.153613  1.000000  0.072154     0.522621
# A_Total             0.126519  0.061471  0.072154  1.000000    -0.046126
# P_Value(in)         0.461952 -0.032318  0.522621 -0.046126     1.000000

# %%
for i in range(city_count): # for each cities
	print(cities_week[i][['Events', 'P_Value(in)']].corr())
# Out:
#                Events  P_Value(in)
# Events       1.000000     0.523511
# P_Value(in)  0.523511     1.000000
#                Events  P_Value(in)
# Events       1.000000     0.522621
# P_Value(in)  0.522621     1.000000
#                Events  P_Value(in)
# Events       1.000000     0.180108
# P_Value(in)  0.180108     1.000000
#                Events  P_Value(in)
# Events       1.000000     0.672076
# P_Value(in)  0.672076     1.000000
#                Events  P_Value(in)
# Events       1.000000     0.599297
# P_Value(in)  0.599297     1.000000

# %%
f, axes = plt.subplots(2, 3, figsize=(25, 15)) # relations between weather count and for all cities

for i in range(city_count):
	sb.heatmap(cities_week[i][['Events', 'P_Value(in)']].corr(), ax = axes[int(i/3),i%3], vmin=0, vmax=1)

# %%
# join plot between weather events and accident count in week for all cities
data = pd.concat([cities_week[0], cities_week[1], cities_week[2], cities_week[3], cities_week[4]],axis=0, ignore_index=True)
data.head()
# Out:
#    Clear  Snow  Fog  Storm  Rain  Precipitation  Cold  Events  A_Total  \
# 0     25     3    0      0     0              0     0       3        0
# 1     20     6    2      0     0              0     0       8        0
# 2     23     4    1      0     0              0     0       5        0
# 3     26     2    0      0     0              0     0       2        0
# 4     18    10    0      0     0              0     0      10        0
#
#    P_Value(in)
# 0         0.39
# 1         0.31
# 2         0.05
# 3         0.00
# 4         0.92

# %% [markdown]
# <h3>Classifcation Tree to predict whether weather cause accident</h3>
#
# Row order:
# 1. Denver
# 2. Miami
# 3. Minneapolis
# 4. New York
# 5. Phoenix

# %%
# Import essential models and functions from sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix


# Recall the Legendary-Total Dataset
for i in range(city_count):
	accident = pd.DataFrame(cities[i]['Accident'])  # Response
	p_val = pd.DataFrame(cities[i]['P_Value(in)'])  # Predictor
	X_train, X_test, y_train, y_test = train_test_split(p_val, accident, test_size = 0.25) # Split the Legendary-Total Dataset into Train and Test
	dectree = DecisionTreeClassifier(max_depth = 4)  # create the decision tree object
	dectree.fit(X_train, y_train)  # train the decision tree model
	y_train_pred = dectree.predict(X_train) # Predict Legendary values corresponding to Total
	y_test_pred = dectree.predict(X_test)
	print("Goodness of Fit of Model \tTrain Dataset") # Check the Goodness of Fit (on Train Data)
	print("Classification Accuracy \t:", dectree.score(X_train, y_train))
	print()
	print("Goodness of Fit of Model \tTest Dataset") # Check the Goodness of Fit (on Test Data)
	print("Classification Accuracy \t:", dectree.score(X_test, y_test))
	print()
	f, axes = plt.subplots(1, 2, figsize=(12, 4)) # Plot the Confusion Matrix for Train and Test
	sb.heatmap(confusion_matrix(y_train, y_train_pred), annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
	sb.heatmap(confusion_matrix(y_test, y_test_pred), annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.6782238442822385
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.6788321167883211
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.8412408759124088
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.7828467153284672
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.7147201946472019
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.666058394160584
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.6690997566909975
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.635036496350365
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.7822384428223844
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.7664233576642335

# %%
# Import essential models and functions from sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix


# Recall the Legendary-Total Dataset
for i in range(city_count):
	accident = pd.DataFrame(cities[i]['Accident'])  # Response
	p_val = pd.DataFrame(cities[i]['P_Value(in)'])  # Predictor
	X_train, X_test, y_train, y_test = train_test_split(p_val, accident, test_size = 0.25) # Split the Legendary-Total Dataset into Train and Test
	dectree = DecisionTreeClassifier(max_depth = 4)  # create the decision tree object
	dectree.fit(X_train, y_train)  # train the decision tree model
	y_train_pred = dectree.predict(X_train) # Predict Legendary values corresponding to Total
	y_test_pred = dectree.predict(X_test)
	print("Goodness of Fit of Model \tTrain Dataset") # Check the Goodness of Fit (on Train Data)
	print("Classification Accuracy \t:", dectree.score(X_train, y_train))
	print()
	print("Goodness of Fit of Model \tTest Dataset") # Check the Goodness of Fit (on Test Data)
	print("Classification Accuracy \t:", dectree.score(X_test, y_test))
	print()
	f, axes = plt.subplots(1, 2, figsize=(12, 4)) # Plot the Confusion Matrix for Train and Test
	sb.heatmap(confusion_matrix(y_train, y_train_pred), annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
	sb.heatmap(confusion_matrix(y_test, y_test_pred), annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.6806569343065694
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.6624087591240876
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.8351581508515815
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.8138686131386861
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.694647201946472
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.708029197080292
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.6636253041362531
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.6496350364963503
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.7822384428223844
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.7737226277372263

# %%
for i in range(city_count):
	accident = pd.DataFrame(cities[i]['Accident'])  # Response
	p_val = pd.DataFrame(cities[i]['P_Value(in)'])  # Predictor
	X_train, X_test, y_train, y_test = train_test_split(p_val, accident, test_size = 0.25) # Split the Legendary-Total Dataset into Train and Test
	sb.catplot(y = "Accident", data = y_train, kind = "count") # Count Plot for Legendary Train
	f, axes = plt.subplots(1, 3, figsize=(12, 2)) # Plot the distributions of Total Train
	sb.boxplot(data = X_train, orient = "h", ax = axes[0])
	sb.histplot(data = X_train, ax = axes[1])
	sb.violinplot(data = X_train, orient = "h", ax = axes[2])
	trainDF = pd.concat([X_train, y_train], axis = 1).reindex(X_train.index) # Create a joint dataframe by concatenating Total and Legendary
	f = plt.figure(figsize=(21, 3)) # Joint Boxplot of Total Train against Legendary Train
	sb.boxplot(x = "P_Value(in)", y = "Accident", data = trainDF, orient = "h")

# %%
<h3>Classifcation Tree to predict whether weather cause accident</h3>

Row order:
1. Denver
2. Miami
3. Minneapolis
4. New York
5. Phoenix
